# %% [markdown]
# ### My version

# %%
import pandas as pd
pd.set_option('display.width', 120)

acc   = pd.read_csv('moneycraft_accounts.csv')        # one row per customer per active month
spend = pd.read_csv('moneycraft_marketing_spend.csv') # one row per month per channel
close = pd.read_csv('moneycraft_closure_reasons.csv') # recorded reasons for SOME closures
