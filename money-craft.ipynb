# %% [markdown]
# # Money Craft Project

# %% [markdown]
# ### Accounts
#
# One row per customer per active month. An account has closed (churned) when its rows stop — there is no churn column.
#
# | column | description |
# |---------------|--------------------------|
# | customer_id |	Unique customer identifier. |
# | month |	Calendar month, e.g. 2023-04. |
# | acquisition_channel |	How the customer was won: Branch, Online, Comparison Site, Outbound, Referral or Broker/IFA. |
# | region | UK region of the customer. |
# | age_band | Customer age group. |
# | account_tier | Packaged tier that month: Classic (£0), Silver (£11), Gold (£18) or Platinum (£28). Can change over time. |
# | monthly_fee |	Fee charged that month (£). Zero on Classic, or while a fee-waiver promo is running. |
# | joined_on_promo |	True if the customer joined on a 6-month fee-waiver promotion. |
#
# ### Closure
#
# Recorded reasons for closed accounts — but only for some of them. This table is deliberately incomplete: many closures have no reason recorded.
#
# | column |	description |
# |--------|--------------|
# | customer_id |	The customer who closed their account. |
# | close_month |	Month the account was closed. |
# | reason_code |	Recorded reason: Fees too high, Switched provider, Poor service, Unhappy with perks, Moved abroad, Bereavement or Unknown. |
#
#
# ### Spend
#
# One row per month per channel: what we spent winning customers.
#
# | column | description |
# |--------|------------|
# | month |	Calendar month. |
# | channel	| Acquisition channel (matches acquisition_channel above). |
# | spend_gbp |	Marketing spend in that channel that month (£). |

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
accounts = pd.read_csv('moneycraft_accounts.csv')

accounts.head()
# Out:
#    customer_id    month acquisition_channel      region age_band account_tier  \
# 0            1  2022-01     Comparison Site    Scotland    25-34      Classic
# 1            2  2022-01              Online      London    55-64       Silver
# 2            3  2022-01              Branch  South East    25-34     Platinum
# 3            4  2022-01            Referral      London    25-34       Silver
# 4            5  2022-01     Comparison Site  South East    35-44       Silver
#
#    monthly_fee  joined_on_promo
# 0            0            False
# 1           11            False
# 2           28            False
# 3            0             True
# 4           11            False

# %% [markdown]
# ## Account nulls

# %%
# any nulls/NaNs will appear as black lines
sns.heatmap(accounts.isnull(), yticklabels=False, cbar=False, cmap="gray_r");

# %%
accounts.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 179018 entries, 0 to 179017
# Data columns (total 8 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   customer_id          179018 non-null  int64
#  1   month                179018 non-null  str
#  2   acquisition_channel  179018 non-null  str
#  3   region               179018 non-null  str
#  4   age_band             179018 non-null  str
#  5   account_tier         179018 non-null  str
#  6   monthly_fee          179018 non-null  int64
#  7   joined_on_promo      179018 non-null  bool
# dtypes: bool(1), int64(2), str(5)
# memory usage: 9.7 MB

# %%
accounts['month'] = pd.PeriodIndex(accounts['month'], freq='M')

# %%
accounts.describe(include='all')
# Out:
#           customer_id    month acquisition_channel  region age_band  \
# count   179018.000000   179018              179018  179018   179018
# unique            NaN       36                   6       6        6
# top               NaN  2024-12              Online  London    25-34
# freq              NaN     9775               43906   42874    45265
# mean      5474.700203      NaN                 NaN     NaN      NaN
# std       3840.562809      NaN                 NaN     NaN      NaN
# min          1.000000      NaN                 NaN     NaN      NaN
# 25%       2209.000000      NaN                 NaN     NaN      NaN
# 50%       4833.000000      NaN                 NaN     NaN      NaN
# 75%       8237.000000      NaN                 NaN     NaN      NaN
# max      15732.000000      NaN                 NaN     NaN      NaN
#
#        account_tier    monthly_fee joined_on_promo
# count        179018  179018.000000          179018
# unique            4            NaN               2
# top          Silver            NaN           False
# freq          57256            NaN          115271
# mean            NaN      12.234200             NaN
# std             NaN       9.807629             NaN
# min             NaN       0.000000             NaN
# 25%             NaN       0.000000             NaN
# 50%             NaN      11.000000             NaN
# 75%             NaN      18.000000             NaN
# max             NaN      28.000000             NaN

# %%
accounts['month'].unique()
# Out:
# <PeriodArray>
# ['2022-01', '2022-02', '2022-03', '2022-04', '2022-05', '2022-06', '2022-07',
#  '2022-08', '2022-09', '2022-10', '2022-11', '2022-12', '2023-01', '2023-02',
#  '2023-03', '2023-04', '2023-05', '2023-06', '2023-07', '2023-08', '2023-09',
#  '2023-10', '2023-11', '2023-12', '2024-01', '2024-02', '2024-03', '2024-04',
#  '2024-05', '2024-06', '2024-07', '2024-08', '2024-09', '2024-10', '2024-11',
#  '2024-12']
# Length: 36, dtype: period[M]

# %% [markdown]
# Accounts data covers Jan 2022 - December 2024.
#
# As per the description of the accounts dataset: 'One row per customer per active month. An account has closed (churned) when its rows stop'
# >Any customer ids which do not have a 2024-12 month row can be considered to have churned.

# %%
closure = pd.read_csv('moneycraft_closure_reasons.csv')

closure.head()
# Out:
#    customer_id close_month         reason_code
# 0        10755     2024-05   Switched provider
# 1         7582     2025-01  Unhappy with perks
# 2         2162     2024-11       Fees too high
# 3         3016     2023-02   Switched provider
# 4          564     2022-07        Poor service

# %% [markdown]
# ## Closure nulls

# %%
sns.heatmap(closure.isnull(), yticklabels=False, cbar=False, cmap="gray_r");

# %%
closure.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4023 entries, 0 to 4022
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   customer_id  4023 non-null   int64
#  1   close_month  4023 non-null   str
#  2   reason_code  4023 non-null   str
# dtypes: int64(1), str(2)
# memory usage: 94.4 KB

# %%
closure['close_month'] = pd.PeriodIndex(closure['close_month'], freq='M')

# %%
closure.describe(include='all')
# Out:
#          customer_id close_month    reason_code
# count    4023.000000        4023           4023
# unique           NaN          36              7
# top              NaN     2025-01  Fees too high
# freq             NaN         211           1268
# mean     5963.338802         NaN            NaN
# std      3998.635024         NaN            NaN
# min         1.000000         NaN            NaN
# 25%      2585.500000         NaN            NaN
# 50%      5374.000000         NaN            NaN
# 75%      8905.000000         NaN            NaN
# max     15716.000000         NaN            NaN

# %% [markdown]
# The closure month column extends into Jan 2025 (the most recent date available). This means any customers who have a flagged close_month can also be considered as churned.

# %%
spend = pd.read_csv('moneycraft_marketing_spend.csv')

spend.head()
# Out:
#      month          channel  spend_gbp
# 0  2022-01           Branch     7310.0
# 1  2022-01       Broker/IFA     4014.0
# 2  2022-01  Comparison Site     3162.0
# 3  2022-01           Online     3945.0
# 4  2022-01         Outbound     4899.0

# %% [markdown]
# ## Spend nulls

# %%
sns.heatmap(spend.isnull(), yticklabels=False, cbar=False, cmap="gray_r");

# %%
spend.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 216 entries, 0 to 215
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   month      216 non-null    str
#  1   channel    216 non-null    str
#  2   spend_gbp  216 non-null    float64
# dtypes: float64(1), str(2)
# memory usage: 5.2 KB

# %%
spend['month'] = pd.PeriodIndex(spend['month'], freq='M')

# %%
spend.describe(include='all')
# Out:
#           month channel     spend_gbp
# count       216     216    216.000000
# unique       36       6           NaN
# top     2022-01  Branch           NaN
# freq          6      36           NaN
# mean        NaN     NaN   6368.518519
# std         NaN     NaN   2846.043225
# min         NaN     NaN   1526.000000
# 25%         NaN     NaN   4413.500000
# 50%         NaN     NaN   6036.500000
# 75%         NaN     NaN   8040.000000
# max         NaN     NaN  14501.000000

# %% [markdown]
# ## Sanity-check the headline claims against the data

# %% [markdown]
# Headline claims ~15,700 fee paying customers.

# %%
accounts['customer_id'].nunique()
# Out:
# 15732

# %%
accounts['monthly_fee'].sum()
# Out:
# np.int64(2190142)

# %% [markdown]
# ## Consolidating the Data

# %%
combined = pd.merge(left=accounts, right=closure, how='left', on='customer_id')

combined.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 179018 entries, 0 to 179017
# Data columns (total 10 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   customer_id          179018 non-null  int64
#  1   month                179018 non-null  period[M]
#  2   acquisition_channel  179018 non-null  str
#  3   region               179018 non-null  str
#  4   age_band             179018 non-null  str
#  5   account_tier         179018 non-null  str
#  6   monthly_fee          179018 non-null  int64
#  7   joined_on_promo      179018 non-null  bool
#  8   close_month          32883 non-null   period[M]
#  9   reason_code          32883 non-null   str
# dtypes: bool(1), int64(2), period[M](2), str(5)
# memory usage: 12.5 MB

# %%
combined.head()
# Out:
#    customer_id    month acquisition_channel      region age_band account_tier  \
# 0            1  2022-01     Comparison Site    Scotland    25-34      Classic
# 1            2  2022-01              Online      London    55-64       Silver
# 2            3  2022-01              Branch  South East    25-34     Platinum
# 3            4  2022-01            Referral      London    25-34       Silver
# 4            5  2022-01     Comparison Site  South East    35-44       Silver
#
#    monthly_fee  joined_on_promo close_month        reason_code
# 0            0            False     2022-07  Switched provider
# 1           11            False         NaT                NaN
# 2           28            False         NaT                NaN
# 3            0             True         NaT                NaN
# 4           11            False     2022-11        Bereavement

# %%
combined['close_month'].max()
# Out:
# Period('2025-01', 'M')

# %%
# combined[combined['close_month'] == pd.Period('2025-01', 'M')]
combined[combined['customer_id'] == 376]
# Out:
#         customer_id    month acquisition_channel    region age_band  \
# 640             376  2022-02              Branch  Scotland    55-64
# 1179            376  2022-03              Branch  Scotland    55-64
# 1989            376  2022-04              Branch  Scotland    55-64
# 3059            376  2022-05              Branch  Scotland    55-64
# 4392            376  2022-06              Branch  Scotland    55-64
# 5973            376  2022-07              Branch  Scotland    55-64
# 7825            376  2022-08              Branch  Scotland    55-64
# 9977            376  2022-09              Branch  Scotland    55-64
# 12410           376  2022-10              Branch  Scotland    55-64
# 15105           376  2022-11              Branch  Scotland    55-64
# 18076           376  2022-12              Branch  Scotland    55-64
# 21326           376  2023-01              Branch  Scotland    55-64
# 24862           376  2023-02              Branch  Scotland    55-64
# 28630           376  2023-03              Branch  Scotland    55-64
# 32679           376  2023-04              Branch  Scotland    55-64
# 37030           376  2023-05              Branch  Scotland    55-64
# 41613           376  2023-06              Branch  Scotland    55-64
# 46470           376  2023-07              Branch  Scotland    55-64
# 51572           376  2023-08              Branch  Scotland    55-64
# 56918           376  2023-09              Branch  Scotland    55-64
# 62485           376  2023-10              Branch  Scotland    55-64
# 68327           376  2023-11              Branch  Scotland    55-64
# 74404           376  2023-12              Branch  Scotland    55-64
# 80774           376  2024-01              Branch  Scotland    55-64
# 87460           376  2024-02              Branch  Scotland    55-64
# 94432           376  2024-03              Branch  Scotland    55-64
# 101625          376  2024-04              Branch  Scotland    55-64
# 109101          376  2024-05              Branch  Scotland    55-64
# 116891          376  2024-06              Branch  Scotland    55-64
# 124969          376  2024-07              Branch  Scotland    55-64
# 133284          376  2024-08              Branch  Scotland    55-64
# 141887          376  2024-09              Branch  Scotland    55-64
# 150751          376  2024-10              Branch  Scotland    55-64
# 159895          376  2024-11              Branch  Scotland    55-64
# 169391          376  2024-12              Branch  Scotland    55-64
#
#        account_tier  monthly_fee  joined_on_promo close_month reason_code
# 640         Classic            0            False     2025-01     Unknown
# 1179        Classic            0            False     2025-01     Unknown
# 1989        Classic            0            False     2025-01     Unknown
# 3059        Classic            0            False     2025-01     Unknown
# 4392        Classic            0            False     2025-01     Unknown
# 5973        Classic            0            False     2025-01     Unknown
# 7825        Classic            0            False     2025-01     Unknown
# 9977        Classic            0            False     2025-01     Unknown
# 12410       Classic            0            False     2025-01     Unknown
# 15105       Classic            0            False     2025-01     Unknown
# 18076       Classic            0            False     2025-01     Unknown
# 21326       Classic            0            False     2025-01     Unknown
# 24862       Classic            0            False     2025-01     Unknown
# 28630       Classic            0            False     2025-01     Unknown
# 32679       Classic            0            False     2025-01     Unknown
# 37030       Classic            0            False     2025-01     Unknown
# 41613       Classic            0            False     2025-01     Unknown
# 46470       Classic            0            False     2025-01     Unknown
# 51572       Classic            0            False     2025-01     Unknown
# 56918       Classic            0            False     2025-01     Unknown
# 62485       Classic            0            False     2025-01     Unknown
# 68327       Classic            0            False     2025-01     Unknown
# 74404       Classic            0            False     2025-01     Unknown
# 80774       Classic            0            False     2025-01     Unknown
# 87460       Classic            0            False     2025-01     Unknown
# 94432       Classic            0            False     2025-01     Unknown
# 101625      Classic            0            False     2025-01     Unknown
# 109101      Classic            0            False     2025-01     Unknown
# 116891      Classic            0            False     2025-01     Unknown
# 124969      Classic            0            False     2025-01     Unknown
# 133284      Classic            0            False     2025-01     Unknown
# 141887      Classic            0            False     2025-01     Unknown
# 150751      Classic            0            False     2025-01     Unknown
# 159895      Classic            0            False     2025-01     Unknown
# 169391      Classic            0            False     2025-01     Unknown

# %% [markdown]
# ## Single Customer View

# %%
combined = combined.sort_values(['customer_id', 'month'], ascending=[True, True])

combined.head()
# Out:
#       customer_id    month acquisition_channel    region age_band  \
# 0               1  2022-01     Comparison Site  Scotland    25-34
# 280             1  2022-02     Comparison Site  Scotland    25-34
# 840             1  2022-03     Comparison Site  Scotland    25-34
# 1664            1  2022-04     Comparison Site  Scotland    25-34
# 2750            1  2022-05     Comparison Site  Scotland    25-34
#
#      account_tier  monthly_fee  joined_on_promo close_month        reason_code
# 0         Classic            0            False     2022-07  Switched provider
# 280       Classic            0            False     2022-07  Switched provider
# 840       Classic            0            False     2022-07  Switched provider
# 1664      Classic            0            False     2022-07  Switched provider
# 2750      Classic            0            False     2022-07  Switched provider

# %%
combined[combined['customer_id'] == 8]
# Out:
#         customer_id    month acquisition_channel      region age_band  \
# 7                 8  2022-01              Online  South East    45-54
# 287               8  2022-02              Online  South East    45-54
# 847               8  2022-03              Online  South East    45-54
# 1671              8  2022-04              Online  South East    45-54
# 2757              8  2022-05              Online  South East    45-54
# 4102              8  2022-06              Online  South East    45-54
# 5692              8  2022-07              Online  South East    45-54
# 7554              8  2022-08              Online  South East    45-54
# 9719              8  2022-09              Online  South East    45-54
# 12162             8  2022-10              Online  South East    45-54
# 14862             8  2022-11              Online  South East    45-54
# 17842             8  2022-12              Online  South East    45-54
# 21102             8  2023-01              Online  South East    45-54
# 24645             8  2023-02              Online  South East    45-54
# 28418             8  2023-03              Online  South East    45-54
# 32473             8  2023-04              Online  South East    45-54
# 36827             8  2023-05              Online  South East    45-54
# 41414             8  2023-06              Online  South East    45-54
# 46276             8  2023-07              Online  South East    45-54
# 51380             8  2023-08              Online  South East    45-54
# 56730             8  2023-09              Online  South East    45-54
# 62299             8  2023-10              Online  South East    45-54
# 68142             8  2023-11              Online  South East    45-54
# 74223             8  2023-12              Online  South East    45-54
# 80595             8  2024-01              Online  South East    45-54
# 87284             8  2024-02              Online  South East    45-54
# 94258             8  2024-03              Online  South East    45-54
# 101454            8  2024-04              Online  South East    45-54
# 108934            8  2024-05              Online  South East    45-54
# 116728            8  2024-06              Online  South East    45-54
# 124811            8  2024-07              Online  South East    45-54
# 133130            8  2024-08              Online  South East    45-54
# 141734            8  2024-09              Online  South East    45-54
# 150599            8  2024-10              Online  South East    45-54
# 159746            8  2024-11              Online  South East    45-54
# 169247            8  2024-12              Online  South East    45-54
#
#        account_tier  monthly_fee  joined_on_promo close_month reason_code
# 7            Silver           11            False         NaT         NaN
# 287          Silver           11            False         NaT         NaN
# 847          Silver           11            False         NaT         NaN
# 1671         Silver           11            False         NaT         NaN
# 2757         Silver           11            False         NaT         NaN
# 4102         Silver           11            False         NaT         NaN
# 5692         Silver           11            False         NaT         NaN
# 7554         Silver           11            False         NaT         NaN
# 9719         Silver           11            False         NaT         NaN
# 12162        Silver           11            False         NaT         NaN
# 14862        Silver           11            False         NaT         NaN
# 17842        Silver           11            False         NaT         NaN
# 21102        Silver           11            False         NaT         NaN
# 24645        Silver           11            False         NaT         NaN
# 28418        Silver           11            False         NaT         NaN
# 32473        Silver           11            False         NaT         NaN
# 36827        Silver           11            False         NaT         NaN
# 41414        Silver           11            False         NaT         NaN
# 46276        Silver           11            False         NaT         NaN
# 51380        Silver           11            False         NaT         NaN
# 56730          Gold           18            False         NaT         NaN
# 62299          Gold           18            False         NaT         NaN
# 68142          Gold           18            False         NaT         NaN
# 74223          Gold           18            False         NaT         NaN
# 80595          Gold           18            False         NaT         NaN
# 87284          Gold           18            False         NaT         NaN
# 94258          Gold           18            False         NaT         NaN
# 101454         Gold           18            False         NaT         NaN
# 108934         Gold           18            False         NaT         NaN
# 116728         Gold           18            False         NaT         NaN
# 124811         Gold           18            False         NaT         NaN
# 133130         Gold           18            False         NaT         NaN
# 141734         Gold           18            False         NaT         NaN
# 150599         Gold           18            False         NaT         NaN
# 159746         Gold           18            False         NaT         NaN
# 169247         Gold           18            False         NaT         NaN

# %%
grouped = combined.groupby('customer_id')

signup_month  = grouped['month'].min()               # their FIRST month
last_active   = grouped['month'].max()               # their LAST month
tenure_months = grouped['month'].count()             # how many months in total
reason_code = grouped['reason_code'].first()         # reason for churning (if available). For customers that have not churned, will be NaN
first_account_tier = grouped['account_tier'].first() # the account tier the customer joined on
last_account_tier = grouped['account_tier'].last()   # the account tier they ended with (if churned) / currently are using (if still active)
region = grouped['region'].last()                    # customers most recent region
channel = grouped['acquisition_channel'].first()     # the channel the customer was first acquired through
age_band = grouped['age_band'].last()                # the customers most recent age band
promo = grouped['joined_on_promo'].first()           # whether the customer joined on a promotion
close_month = grouped['close_month'].last()          # customer close month (if available)


total_revenue = grouped['monthly_fee'].sum()         # total revenue the customer has brought in over their tenure
max_fee = grouped['monthly_fee'].max()               # maximum fee paid during tenure

# %%
scv = pd.DataFrame({
    'signup_month' : signup_month,
    'last_active'  : last_active,
    'close_month'  : close_month,
    'reason_code'  : reason_code,
    'tenure_months': tenure_months,
    'channel'      : channel,
    'region'       : region,
    'age_band'     : age_band,
    'promo'        : promo,
    'first_account_tier' : first_account_tier,
    'last_account_tier' : last_account_tier,
    'max_fee'      : max_fee,
    'total_revenue': total_revenue
})

final_month = combined['month'].max()
scv['churned'] = scv['last_active'] < final_month    # create a churned flag - any customer ids with last active months less than '2024-12' are assumed to have churned

scv.head()
# Out:
#             signup_month last_active close_month        reason_code  \
# customer_id
# 1                2022-01     2022-06     2022-07  Switched provider
# 2                2022-01     2024-12         NaT                NaN
# 3                2022-01     2024-12         NaT                NaN
# 4                2022-01     2024-12         NaT                NaN
# 5                2022-01     2022-10     2022-11        Bereavement
#
#              tenure_months          channel      region age_band  promo  \
# customer_id
# 1                        6  Comparison Site    Scotland    25-34  False
# 2                       36           Online      London    55-64  False
# 3                       36           Branch  South East    25-34  False
# 4                       36         Referral      London    25-34   True
# 5                       10  Comparison Site  South East    35-44  False
#
#             first_account_tier last_account_tier  max_fee  total_revenue  \
# customer_id
# 1                      Classic           Classic        0              0
# 2                       Silver          Platinum       28            595
# 3                     Platinum          Platinum       28            848
# 4                       Silver            Silver       11            330
# 5                       Silver           Classic       11             33
#
#              churned
# customer_id
# 1               True
# 2              False
# 3              False
# 4              False
# 5               True

# %%
# there are some customers which are incorrectly flagged as having not churned when considering the additional closure data
scv[(scv['churned'] == False) & ~(scv['close_month'].isnull())]
# Out:
#             signup_month last_active close_month        reason_code  \
# customer_id
# 376              2022-02     2024-12     2025-01            Unknown
# 443              2022-02     2024-12     2025-01       Poor service
# 792              2022-03     2024-12     2025-01      Fees too high
# 1233             2022-05     2024-12     2025-01  Switched provider
# 1550             2022-06     2024-12     2025-01            Unknown
# ...                  ...         ...         ...                ...
# 15645            2024-12     2024-12     2025-01            Unknown
# 15676            2024-12     2024-12     2025-01      Fees too high
# 15678            2024-12     2024-12     2025-01            Unknown
# 15689            2024-12     2024-12     2025-01       Poor service
# 15716            2024-12     2024-12     2025-01            Unknown
#
#              tenure_months          channel      region age_band  promo  \
# customer_id
# 376                     35           Branch    Scotland    55-64  False
# 443                     35         Outbound  South East    45-54   True
# 792                     34  Comparison Site      London    18-24   True
# 1233                    32         Outbound      London    25-34  False
# 1550                    31  Comparison Site  South East    25-34   True
# ...                    ...              ...         ...      ...    ...
# 15645                    1  Comparison Site      London    25-34   True
# 15676                    1  Comparison Site  Wales & NI    45-54   True
# 15678                    1           Online       North    25-34  False
# 15689                    1         Outbound  South East    35-44  False
# 15716                    1           Online      London    25-34  False
#
#             first_account_tier last_account_tier  max_fee  total_revenue  \
# customer_id
# 376                    Classic           Classic        0              0
# 443                    Classic            Silver       18            263
# 792                     Silver              Gold       18            455
# 1233                      Gold            Silver       18            506
# 1550                    Silver           Classic       11             44
# ...                        ...               ...      ...            ...
# 15645                   Silver            Silver        0              0
# 15676                   Silver            Silver        0              0
# 15678                  Classic           Classic        0              0
# 15689                  Classic           Classic        0              0
# 15716                  Classic           Classic        0              0
#
#              churned
# customer_id
# 376            False
# 443            False
# 792            False
# 1233           False
# 1550           False
# ...              ...
# 15645          False
# 15676          False
# 15678          False
# 15689          False
# 15716          False
#
# [211 rows x 14 columns]

# %%
# update all incorrect churned flags. any customer with a non-null close_month should be flagged as churned.

rows_to_update = scv[(scv['churned'] == False) & ~(scv['close_month'].isnull())].index

scv.loc[rows_to_update, 'churned'] = True

# %%
# verify rows have been updated
scv[(scv['churned'] == False) & ~(scv['close_month'].isnull())]
# Out:
# Empty DataFrame
# Columns: [signup_month, last_active, close_month, reason_code, tenure_months, channel, region, age_band, promo, first_account_tier, last_account_tier, max_fee, total_revenue, churned]
# Index: []

# %%
scv.loc[376,:]
# Out:
# signup_month           2022-02
# last_active            2024-12
# close_month            2025-01
# reason_code            Unknown
# tenure_months               35
# channel                 Branch
# region                Scotland
# age_band                 55-64
# promo                    False
# first_account_tier     Classic
# last_account_tier      Classic
# max_fee                      0
# total_revenue                0
# churned                   True
# Name: 376, dtype: object

# %% [markdown]
# #### Overall Churn Rate

# %%
print(f'''All customers: {scv['churned'].mean():.1%}
Paying customers: {scv[scv['max_fee'] > 0]['churned'].mean():.1%}''')
# Out:
# All customers: 39.2%
# Paying customers: 29.3%
